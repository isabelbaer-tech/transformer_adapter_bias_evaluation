# %% [markdown]
# This notebook loads and saves the pre-trained adapter lm/poem-adapter (https://adapterhub.ml/adapters/ukp/gpt2_lm_poem_pfeiffer/,gtp 2) for the task of Language Modeling.
#  The loadings of pre-trained adapters is done according to: https://colab.research.google.com/github/Adapter-Hub/adapter-transformers/blob/master/notebooks/02_Adapter_Inference.ipynb#scrollTo=Khgmm6OQvvku).

# %%
# !pip install -U git+https://github.com/Adapter-Hub/adapter-transformers.git
# !pip install datasets
# Out:
# ...
#   Cloning https://github.com/Adapter-Hub/adapter-transformers.git to /tmp/pip-req-build-znbva3fl
#   Running command git clone -q https://github.com/Adapter-Hub/adapter-transformers.git /tmp/pip-req-build-znbva3fl
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 895 kB 14.1 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 59.7 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.7 MB/s
# ...
#   Created wheel for adapter-transformers: filename=adapter_transformers-2.1.2-py3-none-any.whl size=2539220 sha256=babca1c2134bf694570e4757b0d0c0c7fbe6424ce134466490812f1c5d5d5250
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uoyqr3fx/wheels/60/0e/d5/86e64fef3085f149b504f48af9ca6e8f6da427f42da9b4bbe5
# Successfully built adapter-transformers
# ...
#      |████████████████████████████████| 264 kB 14.1 MB/s
# ...
#      |████████████████████████████████| 243 kB 66.8 MB/s
# ...

# %%
from google.colab import drive
drive.mount("/content/gdrive/", force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
import sys
path = "/content/gdrive/MyDrive/master_hpi/NLP_Project/code/"
sys.path.append(path)

# %%
from transformers import AutoModelWithHeads, AdapterConfig

model = AutoModelWithHeads.from_pretrained("gpt2")
config = AdapterConfig.load("pfeiffer", non_linearity="relu", reduction_factor=16)
model.load_adapter("lm/poem@ukp", config=config)
model.set_active_adapters("poem")

#model.train_adapter("poem")
# model.config.adapters.adapters
# Out:
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Some weights of GPT2ModelWithHeads were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.10.attn.masked_bias', 'h.11.attn.masked_bias', 'h.9.attn.masked_bias', 'h.1.attn.masked_bias', 'h.0.attn.masked_bias', 'h.4.attn.masked_bias', 'h.7.attn.masked_bias', 'h.6.attn.masked_bias', 'h.2.attn.masked_bias', 'h.5.attn.masked_bias', 'h.8.attn.masked_bias', 'h.3.attn.masked_bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/365 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.60M [00:00<?, ?B/s]

# %%
model.save_adapter(path +"models/lmpoem/", "poem")
